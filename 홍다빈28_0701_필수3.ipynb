# %% [markdown]
# # 필수과제3
# - 상관계수 구하는 식을 확인하고 개념을 정리해서 제출하기

# %% [markdown]
# ### 상관계수란?
# - 두 변수 X,Y의 관계가 얼마나 직선에 가까운지에 대해서 나타내는 수치이다.
# - 상관계수는 -1과 1사이의 값을 가지고 1에 가까울수록 분포가 직선에 가까운 모양이 나온다.
# - 공분산을 각각의 표준편차로 나누어 준 값이라 보면 된다. 측정 단위와 상관없이 두 변수 간의 연광성, 직선적인 경향을 나타내준다.

# %% [markdown]
# #### 모집단 상관계수 공식

# %% [markdown]
# ![%EB%AA%A8%EC%A7%91%EB%8B%A8%EC%9D%98%20%EC%83%81%EA%B4%80%EA%B3%84%EC%88%98%20%EA%B3%B5%EC%8B%9D.png](attachment:%EB%AA%A8%EC%A7%91%EB%8B%A8%EC%9D%98%20%EC%83%81%EA%B4%80%EA%B3%84%EC%88%98%20%EA%B3%B5%EC%8B%9D.png)

# %% [markdown]
# #### 표본 상관계수 공식

# %% [markdown]
# ![%ED%91%9C%EB%B3%B8%EC%9D%98%20%EC%83%81%EA%B4%80%EA%B3%84%EC%88%98%20%EA%B3%B5%EC%8B%9D.png](attachment:%ED%91%9C%EB%B3%B8%EC%9D%98%20%EC%83%81%EA%B4%80%EA%B3%84%EC%88%98%20%EA%B3%B5%EC%8B%9D.png)
